# %%
num=10
while num>=0:
    print(f"i am under the loop!{num}")
    num=num-1 #increment of num
else:
    print("i am now outside the loop")
# Out:
# i am under the loop!10
# i am under the loop!9
# i am under the loop!8
# i am under the loop!7
# i am under the loop!6
# i am under the loop!5
# i am under the loop!4
# i am under the loop!3
# i am under the loop!2
# i am under the loop!1
# i am under the loop!0
# i am now outside the loop

# %%
#printing table
num=int(input("Enter the number of table you want to print"))
start=1
while start<=10:
    print(f"{num}*{start}={num*start}")
    start=start+1
    rerun=int(input("Do you want to continue?:"))
#login system (attempts)
# Out:
# Enter the number of table you want to print 4
# 4*1=4
# Do you want to continue?: 10
# 4*2=8
# Do you want to continue?: 15
# 4*3=12
# Do you want to continue?: 5
# 4*4=16
# Do you want to continue?: 0
# 4*5=20
# Do you want to continue?: no
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 7
#       3 start=1
#       4 while start<=10:
#       5     print(f"{num}*{start}={num*start}")
#       6     start=start+1
# ----> 7     rerun=int(input("Do you want to continue?:"))
#       8 #login system (attempts)
#
# ValueError: invalid literal for int() with base 10: 'no'

# %%
num=10
while num>=0:
    print(f"i am under the loop!{num}")
    num=num-1 #decrement of num
else:
    print("i am now outside the loop")

# %%
#printing table
num=int(input("Enter the number of table you want to print"))
start=1
while start<=10:
    print(f"{num}*{start}={num*start}")
    start=start+1
    
#login system (attempts)
# Out:
# Enter the number of table you want to print 2
# 2*1=2
# 2*2=4
# 2*3=6
# 2*4=8
# 2*5=10
# 2*6=12
# 2*7=14
# 2*8=16
# 2*9=18
# 2*10=20

# %%
#printing table
num=int(input("Enter the number of table you want to print"))
start=1
while start<=10:
    print(f"{num}*{start}={num*start}")
    start=start+1
    rerun=int(input("Do you want to continue?: press any from below:1:No , 2:Yes"))
    if rerun==1:
        print("ok thankyou")
        break
    elif rerun==2:
        print("ok,Continuing..")
        continue
    
#login system (attempts)
# Out:
# Enter the number of table you want to print 2
# 2*1=2
# Do you want to continue?: press any from below:1:No , 2:Yes 2
# ok,Continuing..
# 2*2=4
# Do you want to continue?: press any from below:1:No , 2:Yes 2
# ok,Continuing..
# 2*3=6
# Do you want to continue?: press any from below:1:No , 2:Yes 1
# ok thankyou

# %%
password =input("Enter your pass")
if password==1234:
    print("welcome to laptop of samreen")
elif password==1243:
    print("welcome to laptop of samreen")
elif password==1324:
    print("welcome to laptop of samreen")
else:
    print("this laptop is locked")
# Out:
# Enter your pass 456
# this laptop is locked

# %% [markdown]
# Loggin attempts using loops

# %%
while True:
    username=input("Enter your username:").lower()
    password=input("Enter your password:")
    if (password== "Hello123@" or password== "rafay123" or password== "Helloworld") and username == "rafay":
        print(f"Dear{username}, your password is correct!")
        break
    elif (password=="abc123" and username=="umer"):
        print(f"Dear {username}, your password is correct!")
        break
    else:
        print("incorrect credentials")
    rerun=input("Do you want another try? (yes or no)").lower()
    if rerun=="yes":
        continue
    elif rerun=="no":
        break
# Out:
# Enter your username: rafay
# Enter your password: rafay123
# Dearrafay, your password is correct!

# %%
def avg(num1,num2,num3,num4):
    print(f"This average of four numbers {(num1+num2+num3+num4)/4}")
avg(20,50,60,80)
# Out:
# This average of four numbers 52.5

# %%
def usd(pkr):
    print(f"This is your usd to pkr is {pkr*276}")
usd(1500)
# Out:
# This is your usd to pkr is 414000
