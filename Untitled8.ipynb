# %%
import curr

# %%
usd(14000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 usd(14000)
#
# NameError: name 'usd' is not defined

# %%
USD(14000)

# %%
Usd(14000)

# %%
curr.usd(15000)

# %%
# !pip install pandas

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
pd.read_excel("Ecommerce Sales Analysis.xlsx")

# %%
# !pip install openyxl
