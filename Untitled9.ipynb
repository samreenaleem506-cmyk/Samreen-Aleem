# %%
import pandas as pd

# %%
df=pd.read_csv("cricinfo.csv")

# %%
df.columns
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
#        '100', '50', '0', '4s', '6s'],
#       dtype='str')

# %%
df.rename(columns={'Player':'player','Span':'duration','Mat':'matches','Inns':'innings','NO':'not_out','Runs':'runs','HS':'high_score','Ave':'average','BF':'balls_faced','SR':'strike_rate'})
# Out:
#                player   duration  matches  innings  not_out  runs high_score  \
# 0    DG Bradman (AUS)  1928-1948       52       80       10  6996        334
# 1    PHKD Mendis (SL)  2022-2025       12       21        2  1184       182*
# 2      AC Voges (AUS)  2015-2016       20       31        7  1485       269*
# 3     RG Pollock (SA)  1963-1970       23       41        4  2256        274
# 4     GA Headley (WI)  1930-1954       22       40        4  2190       270*
# ..                ...        ...      ...      ...      ...   ...        ...
# 57   KD Walters (AUS)  1965-1981       74      125       14  5357        250
# 58  GC Smith (ICC/SA)  2002-2014      117      205       13  9265        277
# 59  WH Ponsford (AUS)  1924-1934       29       48        4  2122        266
# 60    SJ McCabe (AUS)  1930-1938       39       62        5  2748        232
# 61   DR Jardine (ENG)  1928-1934       22       33        6  1296        127
#
# ...

# %%
df=df.rename(columns={'Player':'player','Span':'duration','Mat':'matches','Inns':'innings','NO':'not_out','Runs':'runs','HS':'high_score','Ave':'average','BF':'balls_faced','SR':'strike_rate'})

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   player       62 non-null     str
#  1   duration     62 non-null     str
#  2   matches      62 non-null     int64
#  3   innings      62 non-null     int64
#  4   not_out      62 non-null     int64
#  5   runs         62 non-null     int64
#  6   high_score   62 non-null     str
#  7   average      62 non-null     float64
#  8   balls_faced  62 non-null     str
#  9   strike_rate  62 non-null     str
#  10  100          62 non-null     int64
#  11  50           62 non-null     int64
#  12  0            62 non-null     str
#  13  4s           62 non-null     int64
#  14  6s           62 non-null     int64
# dtypes: float64(1), int64(8), str(6)
# memory usage: 9.8 KB

# %%
df{"duration"}
# Out:
#   Cell In[7], line 1
#     df{"duration"}
#       ^
# SyntaxError: invalid syntax

# %%
df.duration

# %%
df['duration'].str.split(pat="-")

# %%
df['duration'].str.split(pat="-".str[0])

# %%
df['duration'].str.split(pat="-").str[0]

# %%
df['start_year']=df['duration'].str.split(pat="-").str[0]

# %%
df['end_year']=df['duration'].str.split(pat="-").str[1]

# %%
df.duration

# %%
df.info()

# %%
df['start_year']=df['start_year'].astype(int)

# %%
df['end_year']=df['end_year'].astype(int)

# %%
df['period']=df['end_year']-df['start_year']

# %%
df.info()

# %%
df['high_score']

# %%
df['high_score'].str.split(pat="*").str[1]

# %%
df['high_score'].str.split(pat="*").str[0]

# %%
df['high_score']=df['high_score'].str.split(pat="*").str[0]

# %%
df['high_score']=df['high_score'].astype(int)

# %%
df.info()

# %%
df['balls_faced']

# %%
df['balls_faced'].str.split(pat="+").str[0]

# %%
df['balls_faced']=df['balls_faced'].str.split(pat="+").str[0]

# %%
df['balls_faced'].astype(int)

# %%
df.info()

# %%
df['balls_faced']=df['balls_faced'].replace("-",0)

# %%
df['balls_faced']=df['balls_faced'].astype(int)

# %%
df.info()

# %%
df['0']=df['0'].replace("-",0)

# %%
df['0']=df['0'].astype(int)

# %%
df.isnull()

# %%
df.isnull()sum()

# %%
df.isnull().sum()

# %%
df

# %%
df.duplicated()

# %%
df.drop.duplicates()

# %%
df=df.drop_duplicates()

# %%
df['player'].str.split(pat="(").str[1]

# %%
df['country']=df['player'].str.split(pat="(").str[1]

# %%
df['country']

# %%
df['country']=df['country'].str.split(pat=")").str[0]

# %%
df['country']

# %%
df.columns

# %%
df(['country','start_year','end_year','period','matches','innings','not_out','runs','high_score','average','balls_faced','strike_rate','100','50','0','4s','6s'])==df

# %%
# !pip install matplotlib

# %%
df['country']=df['player'].str.split(pat="(").str[1]

# %%
df['country']=df['country'].str.split(pat=")").str[0]

# %%
df

# %%
df.to_csv("new_data.csv",index=False)

# %%
 import matplotlib.pyplot as plt

# %%
df.plot(x="player",y="duration")

# %%
df.info()

# %%
df['duration']=df['duration'].astype(int)

# %%
df.plot(kind="bar",x="player",y="duration")

# %%
df.plot(kind="bar",x="player",y="matches")
fig=plt.figure(figsize=(15,10))
fig.set_figwidth(15)

# %%
import matplotlib.pyplot as plt
x=df["country"]
y=df["matches"]

plt.plot(x,y)

# %%
df

# %%
df['player'].str.split(pat="(").str[1]

# %%
df['country']=df['player'].str.split(pat="(").str[1]

# %%
df['country']

# %%
df['country'].str.split(pat=")").str[0]

# %%
df['country']

# %%
df['country'].str.split(pat=")").str[0]

# %%
import matplotlib.pyplot as plt
x=df["country"]
y=df["matches"]

plt.plot(x,y)
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.bar(df['country'],df['matches'],width=0.25,color=["red","blue","green"])
