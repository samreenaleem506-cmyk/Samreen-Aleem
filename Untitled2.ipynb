# %%
while True:
    username=input("Enter your username:").lower()
    password=input("Enter your password:")
    if(password=="Hello123@" or passwword=="rafay123" or password=="Helloworld") and username=="rafay":
        print(f"Dear{username}, your password is correct!")
        break
    elif (password=="abc123" and username=="umer"):
        print(f"Dear {username}, your password is correct!")
        break
    else:
        print("incorrect credentials")
    rerun=input("Do you want another try? (yes or no)").lower()
    if rerun=="yes":
        continue
    elif rerun=="no":
        break
# Out:
# Enter your username: rafay
# Enter your password: rafay123
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 while True:
#       2     username=input("Enter your username:").lower()
#       3     password=input("Enter your password:")
# ----> 4     if(password=="Hello123@" or passwword=="rafay123" or password=="Helloworld") and username=="rafay":
#       5         print(f"Dear{username}, your password is correct!")
#       6         break
#       7     elif (password=="abc123" and username=="umer"):
#
# NameError: name 'passwword' is not defined

# %%
while True:
    num=int(input("Enter a number of table you want to print:"))
    for i in range(1,11):
        print(f"{num}*{i}={num*i}")
    rerun=int(input("Do you want to continue?: Press any from below: 1:No, 2:Yes"))
    if rerun==1:
        print("Ok Thankyou")
        break
    elif rerun==2:
        print("Ok,continue")
        continue
# Out:
# Enter a number of table you want to print: 6
# 6*1=6
# 6*2=12
# 6*3=18
# 6*4=24
# 6*5=30
# 6*6=36
# 6*7=42
# 6*8=48
# 6*9=54
# 6*10=60
# Do you want to continue?: Press any from below: 1:No, 2:Yes 1
# Ok Thankyou
