# %%
import curr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import curr
#
# File ~\OneDrive\Desktop\Python Data analysis\curr.py:5
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
# ----> 5    "execution_count": null,
#       6    "id": "a8adc9c6-c2a9-4ebd-9442-029f40b5297e",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "def usd(pkr):\n",
#      11     "    print (f\"Your USD currency in PKR is {pkr*276})\n",
#      12     "def dirham(pkr):\n",
#      13     "    print (f\"Your Dirham currency in PKR is {pkr*79})\n",
#      14     "def riyal(pkr):\n",
#      15     "    print (f\"Your Riyal currency in PKR is {pkr*81})\n",
#      16     "def euro(pkr):\n",
#      17     "    print (f\"Your Euro currency in PKR is {euro*380})\n",
#      18     "    "
#      19    ]
#      20   }
# ...

# %%
import curr
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\IPython\core\interactiveshell.py:3748 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 1
#     import curr
#
#   File ~\OneDrive\Desktop\Python Data analysis\curr.py:2
#     print (f"Your USD currency in PKR is {pkr*276})
#            ^
# SyntaxError: unterminated f-string literal (detected at line 2)
